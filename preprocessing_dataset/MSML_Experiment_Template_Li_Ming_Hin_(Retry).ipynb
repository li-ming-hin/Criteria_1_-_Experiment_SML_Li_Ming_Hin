# %% [markdown]
# # Criterion 1

# %% [markdown]
# # **1. Introduction to Dataset**

# %% [markdown]
# In the first step, you must find and use a dataset with the following requirements:
#
# 1. **Dataset Source**:
# Datasets can be obtained from various sources, such as public repositories (Kaggle, UCI ML Repository, Open Data) or primary data that you collect yourself.

# %%
# Dataset Used: Heart Disease UCI Dataset
# Source: https://archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# Reason for choosing this dataset:
# - Public and accessible
# - Contains numerical + categorical features
# - Suitable for EDA, preprocessing, and ML pipelines
#
# This notebook will manually perform:
# - Data loading
# - Exploratory Data Analysis (EDA)
# - Preprocessing experiments
#
# Later, these steps will be converted into:
# automate_studentname.py and preprocessing folders
# to satisfy Criteria 2–4.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# At this stage, you need to import several Python libraries needed for data analysis and building machine learning or deep learning models.

# %%
# 2. Import Libraries
# In this section, we import all libraries needed for:
# - Data loading and inspection
# - Exploratory Data Analysis (EDA)
# - Preprocessing (cleaning, encoding, scaling)
# - Basic utilities for handling data

import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing utilities
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

# For organizing warnings (optional but keeps output clean)
import warnings
warnings.filterwarnings('ignore')

print("Libraries successfully imported.")
# Out:
# Libraries successfully imported.

# %% [markdown]
# # **3. Loading Dataset**

# %% [markdown]
# At this stage, you need to load the dataset into your notebook. If the dataset is in CSV format, you can use the pandas library to read it. Be sure to examine the first few lines of the dataset to understand its structure and ensure the data has loaded correctly.
#
# If the dataset is in Google Drive, make sure you connect Google Drive to Colab first. Once the dataset has been successfully loaded, the next step is to verify that the data is suitable for further analysis.
#
# If the dataset is unstructured data, please adapt it to a format such as the Development Machine Learning or Applied Machine Learning classes.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76dc47ab-5ddd-47f4-91f1-2d0093f964fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76dc47ab-5ddd-47f4-91f1-2d0093f964fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("heart_clean.csv")
df.to_csv("heart_raw.csv", index=False)
df.head()
# Out:
#         age       sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  1.564334  0.720325  0.812897 -0.658682 -0.455971  0.0  1.015660 -0.812527
# 1 -0.182473  0.720325 -1.831070 -0.658682 -0.296282  0.0 -0.990736  1.462145
# 2  0.770331 -1.388262  0.812897  0.656232  0.433725  0.0  1.015660  0.626551
# 3 -0.023672 -1.388262  0.812897 -0.658682  2.395617  0.0 -0.990736  0.765817
# 4  0.929131  0.720325  0.812897 -0.001225  0.114347  0.0  1.015660  0.023067
#
#       exang   oldpeak     slope        ca      thal  target
# 0  1.332615  1.533515  0.720799  1.905959  1.129936       1
# 1 -0.750404 -0.197064 -0.985798 -0.821680 -0.925653       0
# 2 -0.750404  2.494947  2.427395  1.905959 -0.925653       3
# 3  1.332615 -0.389350 -0.985798 -0.821680 -0.925653       0
# 4 -0.750404  0.379796  0.720799  0.542139  1.129936       2

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# In this stage, you will conduct **Exploratory Data Analysis (EDA)** to understand the characteristics of the dataset.
#
# The goal of EDA is to gain in-depth initial insights into the data and determine the next steps in analysis or modeling.

# %%
#Type your code here

# 4.1 Check Basic Statistics

df.describe()
# Out:
#                 age           sex            cp      trestbps          chol  \
# count  1.610000e+02  1.610000e+02  1.610000e+02  1.610000e+02  1.610000e+02
# mean  -4.964973e-17 -8.274954e-17 -1.654991e-16  1.379159e-17 -2.206654e-17
# std    1.003120e+00  1.003120e+00  1.003120e+00  1.003120e+00  1.003120e+00
# min   -1.770479e+00 -1.388262e+00 -1.831070e+00 -2.368072e+00 -2.691615e+00
# 25%   -8.176751e-01 -1.388262e+00 -5.090868e-01 -6.586825e-01 -6.840976e-01
# 50%   -2.367214e-02  7.203249e-01  8.128967e-01 -1.225076e-03 -2.252931e-02
# 75%    7.703309e-01  7.203249e-01  8.128967e-01  6.562323e-01  5.934136e-01
# max    2.675938e+00  7.203249e-01  8.128967e-01  2.628605e+00  2.532493e+00
#
#          fbs       restecg       thalach         exang       oldpeak  \
# count  161.0  1.610000e+02  1.610000e+02  1.610000e+02  1.610000e+02
# mean     0.0 -2.758318e-17 -3.309982e-17 -2.758318e-17 -5.516636e-17
# std      0.0  1.003120e+00  1.003120e+00  1.003120e+00  1.003120e+00
# ...

# %%
# 4.2 Check for Missing Values

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 4.3 Check Duplicate Rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 4.4 Identify Numerical & Categorical Columns

numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

numerical_cols, categorical_cols
# Out:
# (Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#         'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#        dtype='object'),
#  Index([], dtype='object'))

# %%
# 4.5-1 Univariate Analysis

# Distribution of Numerical Features

import matplotlib.pyplot as plt
import seaborn as sns

df.hist(figsize=(12, 10), bins=15)
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.show()

# %%
# 4.5-2 Count Plots for Categorical Features

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col)
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# 4.6 Target Variable Distribution

sns.countplot(x=df['target'])
plt.title("Distribution of Target Variable (Heart Disease)")
plt.show()

# %%
# 4.7 Correlation Heatmap (Important for Insights)

plt.figure(figsize=(12, 8))
sns.heatmap(df.drop('age_group', axis=1).corr(), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_944/2256327993.py in <cell line: 0>()
#       2
#       3 plt.figure(figsize=(12, 8))
# ----> 4 sns.heatmap(df.drop('age_group', axis=1).corr(), annot=False, cmap="coolwarm")
#       5 plt.title("Correlation Heatmap")
#       6 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
# 4.8 Boxplots for Outlier Detection

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# At this stage, data preprocessing is a crucial step to ensure data quality before use in a machine learning model.
#
# If you're using text data, the raw data often contains blanks, duplicates, or inconsistent value ranges, which can impact model performance. Therefore, this process aims to clean and prepare the data for optimal analysis.
#
# The following steps can be performed, but are not limited to:
# 1. Removing or Handling Missing Values
# 2. Removing Duplicate Data
# 3. Normalizing or Standardizing Features
# 4. Detecting and Handling Outliers
# 5. Encoding Categorical Data
# 6. Binning (Data Grouping)
#
# Simply adapt this to the characteristics of the data you're using, especially when using unstructured data.

# %%
# 5.1 Handling Missing Values

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# If missing values exist → fill or drop
df = df.dropna()

# %%
# 5.2 Removing Duplicate Data

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
# 5.3 Handling Outliers (IQR Method)

import numpy as np

def remove_outliers(df, cols):
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
df = remove_outliers(df, numerical_cols)

# %%
# 5.4 Encoding Categorical Data

categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index([], dtype='object')

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
# 5.5 Feature Scaling

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = df.drop("target", axis=1)
y = df["target"]

X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame
X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
# 5.6 Final Clean Dataset

df_clean = pd.concat([X, y.reset_index(drop=True)], axis=1)
df_clean.head()
# Out:
#         age       sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  1.569877  0.717137  0.812056 -0.650210 -0.474706  0.0  1.015859 -0.820908
# 1 -0.174542  0.717137 -1.822982 -0.650210 -0.308820  0.0 -0.990620  1.455140
# 2  0.776959 -1.394433  0.812056  0.672674  0.449518  0.0  1.015859  0.619041
# 3 -0.015958 -1.394433  0.812056 -0.650210  2.487550  0.0 -0.990620  0.758391
# 4  0.935543  0.717137  0.812056  0.011232  0.117745  0.0  1.015859  0.015191
#
#       exang   oldpeak     slope        ca      thal  target
# 0  1.337712  1.524250  0.717985  1.898060  1.131697       1
# 1 -0.747545 -0.195941 -0.985890 -0.820783 -0.924758       0
# 2 -0.747545  2.479912  2.421861  1.898060 -0.924758       3
# 3  1.337712 -0.387073 -0.985890 -0.820783 -0.924758       0
# 4 -0.747545  0.377456  0.717985  0.538639  1.131697       2

# %%
# 5.7 Save Preprocessed Dataset

import os

output_dir = "preprocessing_dataset"
os.makedirs(output_dir, exist_ok=True)

df_clean.to_csv(f"{output_dir}/heart_clean.csv", index=False)

print("Preprocessed dataset saved successfully!")
# Out:
# Preprocessed dataset saved successfully!
